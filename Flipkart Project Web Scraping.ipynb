# %% [markdown]
# # Flipkart Web Scraping project

# %% [markdown]
# Flipkart is an Indian e-commerce company, headquartered in Bangalore, Karnataka, India and incorporated in Singapore as a private limited company.The company initially focused on online book sales before expanding into other product categories such as consumer electronics, fashion, home essentials, groceries, and lifestyle products.

# %% [markdown]
# ## Importing Required Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import requests
from bs4 import BeautifulSoup
import re

# %% [markdown]
# Here we will extract the data of mobiles from Flipkart India Website.

# %%
page=requests.get("https://www.flipkart.com/search?q=mobiles&as=on&as-show=on&otracker=AS_Query_TrendingAutoSuggest_1_0_na_na_na&otracker1=AS_Query_TrendingAutoSuggest_1_0_na_na_na&as-pos=1&as-type=TRENDING&suggestionId=mobiles&requestId=3b1db335-1377-4654-bb77-e5c2c1f6cb9c&page=1")

# %%
page
# Out:
# <Response [200]>

# %%
page.text
# Out:
# '<!doctype html><html lang="en"><head><link href="https://rukminim1.flixcart.com" rel="preconnect"/><link rel="stylesheet" href="//static-assets-web.flixcart.com/www/linchpin/fk-cp-zion/css/app_modules.chunk.94b5e7.css"/><link rel="stylesheet" href="//static-assets-web.flixcart.com/www/linchpin/fk-cp-zion/css/app.chunk.dd97f3.css"/><meta http-equiv="Content-type" content="text/html; charset=utf-8"/><meta http-equiv="X-UA-Compatible" content="IE=Edge"/><meta property="fb:page_id" content="102988293558"/><meta property="fb:admins" content="658873552,624500995,100000233612389"/><meta name="robots" content="noodp"/><link rel="shortcut icon" href="https://static-assets-web.flixcart.com/www/promos/new/20150528-140547-favicon-retina.ico"/><link type="application/opensearchdescription+xml" rel="search" href="/osdd.xml?v=2"/><meta property="og:type" content="website"/><meta name="og_site_name" property="og:site_name" content="Flipkart.com"/><link rel="apple-touch-icon" sizes="57x57" href="/ap
# ...

# %%
soup = BeautifulSoup(page.text)

# %%
soup
# Out:
# <!DOCTYPE html>
# ...

# %% [raw]
#  1.mobile_name
#  2.brand
#  3.rating
#  4.ram_memory
#  5.rom_memory
#  6.price
#  7.colour
#  8.front_camera
#  9.back_camera
#  10.required_android
#  11.screen_size
#  12.battery
#  13.processor

# %%
mobile_name = soup.find_all("div",class_="_4rR01T")

# %%
mobile_name = soup.find_all("div",class_="_4rR01T")

mobile_names = []

for i in mobile_name:
    mobile_names.append(i.text.split('(')[0].split(',')[0].strip(' '))
    
mobile_names
# Out:
# ['REDMI 9i Sport',
#  'REDMI 9i Sport',
#  'APPLE iPhone SE',
#  'realme Narzo 50A',
#  'realme Narzo 50A',
#  'REDMI 9i Sport',
#  'realme C21Y',
#  'realme C21Y',
#  'realme C21Y',
#  'realme C21Y',
#  'realme 8i',
#  'POCO C31',
#  'POCO C31',
#  'POCO C31',
#  'realme 8i',
#  'realme 8i',
#  'MOTOROLA G60',
#  'realme C11 2021',
#  'realme C11 2021',
#  'realme Narzo 50i',
#  'realme Narzo 50i',
#  'OPPO A12',
#  'OPPO A12',
#  'OPPO A12']

# %%
mobile_brand = soup.find_all("div",class_="_4rR01T")

# %%
mobile_brand = soup.find_all("div",class_="_4rR01T")

mobile_brands = []

for i in mobile_brand:
    mobile_brands.append(i.text.split(' ')[0].strip(','))
    
mobile_brands
# Out:
# ['REDMI',
#  'REDMI',
#  'APPLE',
#  'realme',
#  'realme',
#  'REDMI',
#  'realme',
#  'realme',
#  'realme',
#  'realme',
#  'realme',
#  'POCO',
#  'POCO',
#  'POCO',
#  'realme',
#  'realme',
#  'MOTOROLA',
#  'realme',
#  'realme',
#  'realme',
#  'realme',
#  'OPPO',
#  'OPPO',
#  'OPPO']

# %%
rating = soup.find_all("div",class_="_3LWZlK")

# %%
rating = soup.find_all("div",class_="_3LWZlK")

ratings = []
count = 0


for i in rating:
    count=count+1
    if count<25 :
        ratings.append(i.text)
        
    
ratings
# Out:
# ['4.4',
#  '4.4',
#  '4.5',
#  '4.4',
#  '4.4',
#  '4.4',
#  '4.5',
#  '4.6',
#  '4.6',
#  '4.5',
#  '4.5',
#  '4.4',
#  '4.4',
#  '4.4',
#  '4.4',
#  '4.4',
#  '4.2',
#  '4.4',
#  '4.4',
#  '4.5',
#  '4.5',
#  '4.4',
#  '4.5',
#  '4.5']

# %%
ram_memory = soup.find_all("li",class_="rgWa7D")
ram_memory
# Out:
# [<li class="rgWa7D">4 GB RAM | 64 GB ROM | Expandable Upto 512 GB</li>,
#  <li class="rgWa7D">16.59 cm (6.53 inch) HD+ Display</li>,
#  <li class="rgWa7D">13MP Rear Camera | 5MP Front Camera</li>,
#  <li class="rgWa7D">5000 mAh Li-Polymer Battery</li>,
#  <li class="rgWa7D">MediaTek Helio G25 Processor</li>,
#  <li class="rgWa7D">Brand Warranty of 1 Year Available for Mobile and 6 Months for Accessories</li>,
#  <li class="rgWa7D">4 GB RAM | 64 GB ROM | Expandable Upto 512 GB</li>,
#  <li class="rgWa7D">16.59 cm (6.53 inch) HD+ Display</li>,
#  <li class="rgWa7D">13MP Rear Camera | 5MP Front Camera</li>,
#  <li class="rgWa7D">5000 mAh Li-Polymer Battery</li>,
#  <li class="rgWa7D">MediaTek Helio G25 Processor</li>,
#  <li class="rgWa7D">Brand Warranty of 1 Year Available for Mobile and 6 Months for Accessories</li>,
#  <li class="rgWa7D">64 GB ROM</li>,
#  <li class="rgWa7D">11.94 cm (4.7 inch) Retina HD Display</li>,
#  <li class="rgWa7D">12MP Rear Camera | 7MP Front Camera</li>,
# ...

# %%
ram_memory = soup.find_all("li",class_="rgWa7D")
ram_memory
import re
ram = []

for i in ram_memory:
    a = re.findall("(\d+)\sGB\sRAM",str(i))
    if a:
        ram.append(a[0])
        
ram
# Out:
# ['4',
#  '4',
#  '4',
#  '4',
#  '4',
#  '4',
#  '3',
#  '3',
#  '4',
#  '4',
#  '4',
#  '3',
#  '3',
#  '6',
#  '6',
#  '6',
#  '2',
#  '2',
#  '2',
#  '2',
#  '3',
#  '4',
#  '4']

# %%
screen_size = []

for i in ram_memory:
    b = re.findall("(\d+.\d+)\sinch",str(i))
    if b:
        screen_size.append(b[0])
        
screen_size
# Out:
# ['6.53',
#  '6.53',
#  '4.7',
#  '6.5',
#  '6.5',
#  '6.53',
#  '6.5',
#  '6.5',
#  '6.5',
#  '6.5',
#  '6.6',
#  '6.53',
#  '6.53',
#  '6.53',
#  '6.6',
#  '6.6',
#  '6.78',
#  '6.5',
#  '6.5',
#  '6.5',
#  '6.5',
#  '6.22',
#  '6.22',
#  '6.22']

# %%
rom_memory = soup.find_all("li",class_="rgWa7D")
rom_memory
# Out:
# [<li class="rgWa7D">4 GB RAM | 64 GB ROM | Expandable Upto 512 GB</li>,
#  <li class="rgWa7D">16.59 cm (6.53 inch) HD+ Display</li>,
#  <li class="rgWa7D">13MP Rear Camera | 5MP Front Camera</li>,
#  <li class="rgWa7D">5000 mAh Li-Polymer Battery</li>,
#  <li class="rgWa7D">MediaTek Helio G25 Processor</li>,
#  <li class="rgWa7D">Brand Warranty of 1 Year Available for Mobile and 6 Months for Accessories</li>,
#  <li class="rgWa7D">4 GB RAM | 64 GB ROM | Expandable Upto 512 GB</li>,
#  <li class="rgWa7D">16.59 cm (6.53 inch) HD+ Display</li>,
#  <li class="rgWa7D">13MP Rear Camera | 5MP Front Camera</li>,
#  <li class="rgWa7D">5000 mAh Li-Polymer Battery</li>,
#  <li class="rgWa7D">MediaTek Helio G25 Processor</li>,
#  <li class="rgWa7D">Brand Warranty of 1 Year Available for Mobile and 6 Months for Accessories</li>,
#  <li class="rgWa7D">64 GB ROM</li>,
#  <li class="rgWa7D">11.94 cm (4.7 inch) Retina HD Display</li>,
#  <li class="rgWa7D">12MP Rear Camera | 7MP Front Camera</li>,
# ...

# %%
rom_memory = soup.find_all("li",class_="rgWa7D")

import re
rom = []

for i in rom_memory:
    a = re.findall("(\d+)\sGB\sROM",str(i))
    if a:
        rom.append(a[0])
        
rom
# Out:
# ['64',
#  '64',
#  '64',
#  '64',
#  '128',
#  '64',
#  '64',
#  '32',
#  '32',
#  '64',
#  '64',
#  '64',
#  '32',
#  '32',
#  '128',
#  '128',
#  '128',
#  '32',
#  '32',
#  '32',
#  '32',
#  '32',
#  '64',
#  '64']

# %%
price = soup.find_all("div",class_="_30jeq3 _1_WHN1")
price
# Out:
# [<div class="_30jeq3 _1_WHN1">₹8,799</div>,
#  <div class="_30jeq3 _1_WHN1">₹8,799</div>,
#  <div class="_30jeq3 _1_WHN1">₹27,999</div>,
#  <div class="_30jeq3 _1_WHN1">₹11,499</div>,
#  <div class="_30jeq3 _1_WHN1">₹12,499</div>,
#  <div class="_30jeq3 _1_WHN1">₹8,799</div>,
#  <div class="_30jeq3 _1_WHN1">₹10,499</div>,
#  <div class="_30jeq3 _1_WHN1">₹9,499</div>,
#  <div class="_30jeq3 _1_WHN1">₹9,499</div>,
#  <div class="_30jeq3 _1_WHN1">₹10,499</div>,
#  <div class="_30jeq3 _1_WHN1">₹13,999</div>,
#  <div class="_30jeq3 _1_WHN1">₹8,999</div>,
#  <div class="_30jeq3 _1_WHN1">₹7,999</div>,
#  <div class="_30jeq3 _1_WHN1">₹7,999</div>,
#  <div class="_30jeq3 _1_WHN1">₹15,999</div>,
#  <div class="_30jeq3 _1_WHN1">₹15,999</div>,
#  <div class="_30jeq3 _1_WHN1">₹16,999</div>,
#  <div class="_30jeq3 _1_WHN1">₹7,499</div>,
#  <div class="_30jeq3 _1_WHN1">₹7,499</div>,
#  <div class="_30jeq3 _1_WHN1">₹7,499</div>,
#  <div class="_30jeq3 _1_WHN1">₹7,499</div>,
# ...

# %%
price = soup.find_all("div",class_="_30jeq3 _1_WHN1")

prices = []

for i in price:
    a = re.findall('[0-9]{1,3},[0-9]*',str(i))
    if a :
        prices.append(i.text)
    
prices
# Out:
# ['₹8,799',
#  '₹8,799',
#  '₹27,999',
#  '₹11,499',
#  '₹12,499',
#  '₹8,799',
#  '₹10,499',
#  '₹9,499',
#  '₹9,499',
#  '₹10,499',
#  '₹13,999',
#  '₹8,999',
#  '₹7,999',
#  '₹7,999',
#  '₹15,999',
#  '₹15,999',
#  '₹16,999',
#  '₹7,499',
#  '₹7,499',
#  '₹7,499',
#  '₹7,499',
#  '₹9,990',
#  '₹10,990',
#  '₹10,990']

# %%
front_camera = soup.find_all('li',class_="rgWa7D")

front_camera
# Out:
# [<li class="rgWa7D">4 GB RAM | 64 GB ROM | Expandable Upto 512 GB</li>,
#  <li class="rgWa7D">16.59 cm (6.53 inch) HD+ Display</li>,
#  <li class="rgWa7D">13MP Rear Camera | 5MP Front Camera</li>,
#  <li class="rgWa7D">5000 mAh Li-Polymer Battery</li>,
#  <li class="rgWa7D">MediaTek Helio G25 Processor</li>,
#  <li class="rgWa7D">Brand Warranty of 1 Year Available for Mobile and 6 Months for Accessories</li>,
#  <li class="rgWa7D">4 GB RAM | 64 GB ROM | Expandable Upto 512 GB</li>,
#  <li class="rgWa7D">16.59 cm (6.53 inch) HD+ Display</li>,
#  <li class="rgWa7D">13MP Rear Camera | 5MP Front Camera</li>,
#  <li class="rgWa7D">5000 mAh Li-Polymer Battery</li>,
#  <li class="rgWa7D">MediaTek Helio G25 Processor</li>,
#  <li class="rgWa7D">Brand Warranty of 1 Year Available for Mobile and 6 Months for Accessories</li>,
#  <li class="rgWa7D">64 GB ROM</li>,
#  <li class="rgWa7D">11.94 cm (4.7 inch) Retina HD Display</li>,
#  <li class="rgWa7D">12MP Rear Camera | 7MP Front Camera</li>,
# ...

# %%
front_camera = soup.find_all('li',class_="rgWa7D")

front_cameras = []

for i in front_camera:
    a = re.findall('(\d)MP Front Camera',str(i))
    if a:
        front_cameras.append(i.text.split('|')[-1].strip(' '))
    
front_cameras
# Out:
# ['5MP Front Camera',
#  '5MP Front Camera',
#  '7MP Front Camera',
#  '8MP Front Camera',
#  '8MP Front Camera',
#  '5MP Front Camera',
#  '5MP Front Camera',
#  '5MP Front Camera',
#  '5MP Front Camera',
#  '5MP Front Camera',
#  '16MP Front Camera',
#  '5MP Front Camera',
#  '5MP Front Camera',
#  '5MP Front Camera',
#  '16MP Front Camera',
#  '16MP Front Camera',
#  '32MP Front Camera',
#  '5MP Front Camera',
#  '5MP Front Camera',
#  '5MP Front Camera',
#  '5MP Front Camera',
#  '5MP Front Camera',
#  '5MP Front Camera',
#  '5MP Front Camera']

# %%
back_camera = soup.find_all('li',class_="rgWa7D")


back_camera
# Out:
# [<li class="rgWa7D">4 GB RAM | 64 GB ROM | Expandable Upto 512 GB</li>,
#  <li class="rgWa7D">16.59 cm (6.53 inch) HD+ Display</li>,
#  <li class="rgWa7D">13MP Rear Camera | 5MP Front Camera</li>,
#  <li class="rgWa7D">5000 mAh Li-Polymer Battery</li>,
#  <li class="rgWa7D">MediaTek Helio G25 Processor</li>,
#  <li class="rgWa7D">Brand Warranty of 1 Year Available for Mobile and 6 Months for Accessories</li>,
#  <li class="rgWa7D">4 GB RAM | 64 GB ROM | Expandable Upto 512 GB</li>,
#  <li class="rgWa7D">16.59 cm (6.53 inch) HD+ Display</li>,
#  <li class="rgWa7D">13MP Rear Camera | 5MP Front Camera</li>,
#  <li class="rgWa7D">5000 mAh Li-Polymer Battery</li>,
#  <li class="rgWa7D">MediaTek Helio G25 Processor</li>,
#  <li class="rgWa7D">Brand Warranty of 1 Year Available for Mobile and 6 Months for Accessories</li>,
#  <li class="rgWa7D">64 GB ROM</li>,
#  <li class="rgWa7D">11.94 cm (4.7 inch) Retina HD Display</li>,
#  <li class="rgWa7D">12MP Rear Camera | 7MP Front Camera</li>,
# ...

# %%
back_camera = soup.find_all('li',class_="rgWa7D")

back_cameras = []

for i in back_camera:
    a = re.findall('(\d)MP Front Camera',str(i))
    if a:
        back_cameras.append(i.text.split('|')[0].strip(' '))
    
back_cameras
# Out:
# ['13MP Rear Camera',
#  '13MP Rear Camera',
#  '12MP Rear Camera',
#  '50MP + 2MP + 2MP',
#  '50MP + 2MP + 2MP',
#  '13MP Rear Camera',
#  '13MP + 2MP + 2MP',
#  '13MP + 2MP + 2MP',
#  '13MP + 2MP + 2MP',
#  '13MP + 2MP + 2MP',
#  '50MP + 2MP + 2MP',
#  '13MP + 2MP + 2MP',
#  '13MP + 2MP + 2MP',
#  '13MP + 2MP + 2MP',
#  '50MP + 2MP + 2MP',
#  '50MP + 2MP + 2MP',
#  '108MP + 8MP + 2MP',
#  '8MP Rear Camera',
#  '8MP Rear Camera',
#  '8MP Rear Camera',
#  '8MP Rear Camera',
#  '13MP + 2MP',
#  '13MP + 2MP',
#  '13MP + 2MP']

# %%
color = soup.find_all('div' , class_ = '_4rR01T')

color
# Out:
# [<div class="_4rR01T">REDMI 9i Sport (Metallic Blue, 64 GB)</div>,
#  <div class="_4rR01T">REDMI 9i Sport (Coral Green, 64 GB)</div>,
#  <div class="_4rR01T">APPLE iPhone SE (Red, 64 GB)</div>,
#  <div class="_4rR01T">realme Narzo 50A (Oxygen Green, 64 GB)</div>,
#  <div class="_4rR01T">realme Narzo 50A (Oxygen Blue, 128 GB)</div>,
#  <div class="_4rR01T">REDMI 9i Sport (Carbon Black, 64 GB)</div>,
#  <div class="_4rR01T">realme C21Y (Cross Black, 64 GB)</div>,
#  <div class="_4rR01T">realme C21Y (Cross Blue, 32 GB)</div>,
#  <div class="_4rR01T">realme C21Y (Cross Black, 32 GB)</div>,
#  <div class="_4rR01T">realme C21Y (Cross Blue, 64 GB)</div>,
#  <div class="_4rR01T">realme 8i (Space Black, 64 GB)</div>,
#  <div class="_4rR01T">POCO C31 (Shadow Gray, 64 GB)</div>,
#  <div class="_4rR01T">POCO C31 (Royal Blue, 32 GB)</div>,
#  <div class="_4rR01T">POCO C31 (Shadow Gray, 32 GB)</div>,
#  <div class="_4rR01T">realme 8i (Space Purple, 128 GB)</div>,
# ...

# %%
color = soup.find_all('div' , class_ = '_4rR01T')

colours = []

for i in color:
    colours.append(i.text.split('(')[-1].split(',')[0])
    
    
colours
# Out:
# ['Metallic Blue',
#  'Coral Green',
#  'Red',
#  'Oxygen Green',
#  'Oxygen Blue',
#  'Carbon Black',
#  'Cross Black',
#  'Cross Blue',
#  'Cross Black',
#  'Cross Blue',
#  'Space Black',
#  'Shadow Gray',
#  'Royal Blue',
#  'Shadow Gray',
#  'Space Purple',
#  'Space Black',
#  'Frosted Champagne',
#  'Cool Grey',
#  'Cool Blue',
#  'Mint Green',
#  'Carbon Black',
#  'Black',
#  'Flowing Silver',
#  'Blue']

# %%
battery = soup.find_all('li',class_="rgWa7D")

battery
# Out:
# [<li class="rgWa7D">4 GB RAM | 64 GB ROM | Expandable Upto 512 GB</li>,
#  <li class="rgWa7D">16.59 cm (6.53 inch) HD+ Display</li>,
#  <li class="rgWa7D">13MP Rear Camera | 5MP Front Camera</li>,
#  <li class="rgWa7D">5000 mAh Li-Polymer Battery</li>,
#  <li class="rgWa7D">MediaTek Helio G25 Processor</li>,
#  <li class="rgWa7D">Brand Warranty of 1 Year Available for Mobile and 6 Months for Accessories</li>,
#  <li class="rgWa7D">4 GB RAM | 64 GB ROM | Expandable Upto 512 GB</li>,
#  <li class="rgWa7D">16.59 cm (6.53 inch) HD+ Display</li>,
#  <li class="rgWa7D">13MP Rear Camera | 5MP Front Camera</li>,
#  <li class="rgWa7D">5000 mAh Li-Polymer Battery</li>,
#  <li class="rgWa7D">MediaTek Helio G25 Processor</li>,
#  <li class="rgWa7D">Brand Warranty of 1 Year Available for Mobile and 6 Months for Accessories</li>,
#  <li class="rgWa7D">64 GB ROM</li>,
#  <li class="rgWa7D">11.94 cm (4.7 inch) Retina HD Display</li>,
#  <li class="rgWa7D">12MP Rear Camera | 7MP Front Camera</li>,
# ...

# %%
battery = soup.find_all('li',class_="rgWa7D")

batteries_in_mAh = []

for i in battery:
    a = re.findall('(\d+)\smAh',str(i))
    if a:
        batteries_in_mAh.append(i.text.split(' ')[0])
    
batteries_in_mAh
# Out:
# ['5000',
#  '5000',
#  '6000',
#  '6000',
#  '5000',
#  '5000',
#  '5000',
#  '5000',
#  '5000',
#  '5000',
#  '5000',
#  '5000',
#  '5000',
#  '5000',
#  '5000',
#  '6000',
#  '5000',
#  '5000',
#  '5000',
#  '5000',
#  '4230',
#  '4230',
#  '4230']

# %%
processors = soup.find_all('li',class_="rgWa7D")
processors
# Out:
# [<li class="rgWa7D">4 GB RAM | 64 GB ROM | Expandable Upto 512 GB</li>,
#  <li class="rgWa7D">16.59 cm (6.53 inch) HD+ Display</li>,
#  <li class="rgWa7D">13MP Rear Camera | 5MP Front Camera</li>,
#  <li class="rgWa7D">5000 mAh Li-Polymer Battery</li>,
#  <li class="rgWa7D">MediaTek Helio G25 Processor</li>,
#  <li class="rgWa7D">Brand Warranty of 1 Year Available for Mobile and 6 Months for Accessories</li>,
#  <li class="rgWa7D">4 GB RAM | 64 GB ROM | Expandable Upto 512 GB</li>,
#  <li class="rgWa7D">16.59 cm (6.53 inch) HD+ Display</li>,
#  <li class="rgWa7D">13MP Rear Camera | 5MP Front Camera</li>,
#  <li class="rgWa7D">5000 mAh Li-Polymer Battery</li>,
#  <li class="rgWa7D">MediaTek Helio G25 Processor</li>,
#  <li class="rgWa7D">Brand Warranty of 1 Year Available for Mobile and 6 Months for Accessories</li>,
#  <li class="rgWa7D">64 GB ROM</li>,
#  <li class="rgWa7D">11.94 cm (4.7 inch) Retina HD Display</li>,
#  <li class="rgWa7D">12MP Rear Camera | 7MP Front Camera</li>,
# ...

# %%
processors = soup.find_all('li',class_="rgWa7D")

processor= []

for i in processors:
    a = re.findall('[A-Za-z0-9]* Processor',str(i))
    if a:
        processor.append(i.text)
    
processor
# Out:
# ['MediaTek Helio G25 Processor',
#  'MediaTek Helio G25 Processor',
#  'A13 Bionic Chip with 3rd Gen Neural Engine Processor',
#  'MediaTek Helio G85 Processor',
#  'MediaTek Helio G85 Processor',
#  'MediaTek Helio G25 Processor',
#  'Unisoc T610 Processor',
#  'Unisoc T610 Processor',
#  'Unisoc T610 Processor',
#  'Unisoc T610 Processor',
#  'MediaTek Helio G96 Processor',
#  'MediaTek Helio G35 Processor',
#  'MediaTek Helio G35 Processor',
#  'MediaTek Helio G35 Processor',
#  'MediaTek Helio G96 Processor',
#  'MediaTek Helio G96 Processor',
#  'Qualcomm Snapdragon 732G Processor',
#  'Octa-core Processor',
#  'Octa-core Processor',
#  'SC9863A Processor',
#  'SC9863A Processor',
#  'MediaTek Helio P35 Processor',
#  'MediaTek Helio P35 Processor',
#  'MediaTek Helio P35 Processor']

# %% [raw]
# mobile_names
# brand
# ratings
# ram
# rom
# prices
# colours
# front_camera
# back_camera
# required_android
# screen_size
# batteries_in_mAh
# processor

# %%
url = []

for i in range(1,200):
    url.append("https://www.flipkart.com/search?q=mobiles&as=on&as-show=on&otracker=AS_Query_TrendingAutoSuggest_1_0_na_na_na&otracker1=AS_Query_TrendingAutoSuggest_1_0_na_na_na&as-pos=1&as-type=TRENDING&suggestionId=mobiles&requestId=3b1db335-1377-4654-bb77-e5c2c1f6cb9c&page="+str(i))


mobile_names = []
mobile_brands = []
ratings = []
ram = []
screen_size = []
rom = []
prices = []
front_cameras = []
back_cameras = []
colours = []
batteries_in_mAh = []
processor= []


for i in url:
    
    page=requests.get(i)
    page.text
    soup=BeautifulSoup(page.text)
    
    mobile_name = soup.find_all("div",class_="_4rR01T")
    #mobile_names = []


    for i in mobile_name:
        mobile_names.append(i.text.split('(')[0].split(',')[0].strip(' '))



    mobile_brand = soup.find_all("div",class_="_4rR01T")
    #mobile_brands = []


    for i in mobile_brand:
        mobile_brands.append(i.text.split(' ')[0].strip(','))



    rating = soup.find_all("div",class_="_3LWZlK")
    #ratings = []
    count = 0


    for i in rating:
        count=count+1
        if count<25 :
            ratings.append(i.text)




    ram_memory = soup.find_all("li",class_="rgWa7D")
    #ram = []
    

    for i in ram_memory:
        a = re.findall("(\d+)\sGB\sRAM",str(i))
        if a:
            ram.append(a[0])
            


    #screen_size = []  
    
    for i in ram_memory:
        b = re.findall("(\d+.\d+)\sinch",str(i))
        if b:
            screen_size.append(b[0])



    rom_memory = soup.find_all("li",class_="rgWa7D")
    #rom = []

    for i in rom_memory:
        a = re.findall("(\d+)\sGB\sROM",str(i))
        if a:
            rom.append(a[0])


    price = soup.find_all("div",class_="_30jeq3 _1_WHN1")
    
    #prices = []

    for i in price:
        prices.append(i.text)


    front_camera = soup.find_all('li',class_="rgWa7D")
    #front_cameras = []

    for i in front_camera:
        a = re.findall('(\d)MP Front Camera',str(i))
        if a:
            front_cameras.append(i.text.split('|')[-1].strip(' '))


    back_camera = soup.find_all('li',class_="rgWa7D")
    #back_cameras = []

    for i in back_camera:
        a = re.findall('(\d)MP Front Camera',str(i))
        if a:
            back_cameras.append(i.text.split('|')[0].strip(' '))
            
            


    color = soup.find_all('div' , class_ = '_4rR01T')
    #colours = []

    for i in color:
        colours.append(i.text.split('(')[-1].split(',')[0])
        
        



    battery = soup.find_all('li',class_="rgWa7D")
    #batteries_in_mAh = []

    for i in battery:
        a = re.findall('(\d+)\smAh',str(i))
        if a:
            batteries_in_mAh.append(i.text.split(' ')[0])



    processors = soup.find_all('li',class_="rgWa7D")
    #processor = []

    for i in processors:
        a = re.findall('[A-Za-z0-9]* Processor',str(i))
        if a:
            processor.append(i.text)
    


flip = {'mobile_name':mobile_names,
                     'brand':mobile_brands,'rating':ratings,
                     'ram':ram,'rom':rom,'prices':prices,
                     'colours':colours,'front_camera_in_MP':front_cameras,
                     'back_camera_in_MP':back_cameras,'screen_size':screen_size,
                     'batteries_in_mAh':batteries_in_mAh,'processor':processor}


flip = pd.DataFrame.from_dict(flip, orient='index')
flip= flip.transpose()

# %% [markdown]
# # Data Cleaning

# %%
flip.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 960 entries, 0 to 959
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   mobile_name         960 non-null    object
#  1   brand               960 non-null    object
#  2   rating              960 non-null    object
#  3   ram                 494 non-null    object
#  4   rom                 530 non-null    object
#  5   prices              954 non-null    object
#  6   colours             960 non-null    object
#  7   front_camera_in_MP  488 non-null    object
#  8   back_camera_in_MP   488 non-null    object
#  9   screen_size         940 non-null    object
#  10  batteries_in_mAh    923 non-null    object
#  11  processor           534 non-null    object
# dtypes: object(12)
# memory usage: 90.1+ KB

# %% [markdown]
# ### There is null values in ram and batteries in mAh

# %% [markdown]
# ## Unique values in each column

# %%
flip.mobile_name.unique()
# Out:
# array(['REDMI 9i Sport', 'APPLE iPhone SE', 'realme Narzo 50A',
#        'realme C21Y', 'realme 8i', 'POCO C31', 'MOTOROLA G60',
#        'realme C11 2021', 'realme Narzo 50i', 'OPPO A12', 'realme 8',
#        'realme 9i', 'REDMI 9i', 'OPPO A53s 5G', 'MOTOROLA g31',
#        'MOTOROLA E7 Power', 'SAMSUNG Galaxy F22', 'SAMSUNG Galaxy F12',
#        'APPLE iPhone 12 Mini', 'Infinix Hot 11S', 'Infinix Hot 10S',
#        'Infinix Hot 10 Play', 'realme C25Y', 'APPLE iPhone 12',
#        'realme C25_Y', 'Nokia TA-1304/105 SS', 'Xiaomi 11i 5G',
#        'LAVA A1 Josh 2021', 'SAMSUNG Galaxy M32 5G', 'LAVA A3',
#        'realme Narzo 30', 'Micromax X412', 'vivo Y20T', 'LAVA GEM',
#        'SAMSUNG Galaxy F42 5G', 'REDMI Note 10S', 'vivo V23 5G',
#        'LAVA A1500', 'Infinix Note 11s', 'I Kall K 48',
#        'MOTOROLA G40 Fusion', 'MOTOROLA G51 5G', 'LAVA A3 Power',
#        'realme 8s 5G', 'SAMSUNG Galaxy M12', 'vivo Y12G',
#        'SAMSUNG Galaxy M32', 'LAVA A1 2021', 'GIONEE Max',
# ...

# %%
flip.brand.unique()
# Out:
# array(['REDMI', 'APPLE', 'realme', 'POCO', 'MOTOROLA', 'OPPO', 'SAMSUNG',
#        'Infinix', 'Nokia', 'Xiaomi', 'LAVA', 'Micromax', 'vivo', 'I',
#        'GIONEE', 'KARBONN', 'GFive', 'Kechaoda', 'Itel', 'DIZO',
#        'BlackZone', 'Motorola', 'Lava', 'Redmi', 'Salora', 'IAIR',
#        'Grabo', 'Tecno', 'Ismart', 'Maplin', 'BlackBear', 'Google', 'MU',
#        'GREENBERRI', 'MTR', 'Nuvo', 'Mi', 'MI', 'Good', 'Snexian',
#        'Darago', 'Forme', 'Alcatel', 'ENERGIZER', 'Intex', 'Jmax',
#        'Coolpad', 'MarQ', 'Cellecor', 'Infocus', 'PHILIPS', 'Geotel',
#        'Tork', 'INOVU', 'YU', 'Fliky', 'Zoom', 'ringme', 'Easyfone'],
#       dtype=object)

# %%
flip.rating.unique()
# Out:
# array(['4.4', '4.5', '4.6', '4.2', '4.3', '4.1', '4.7', '3.9', '3.7', '4',
#        '3.6', '3.8', '3.3', '5', '3', '3.4', '3.5', '1', '3.2', '2',
#        '3.1'], dtype=object)

# %%
flip.ram.unique()
# Out:
# array(['4', '3', '6', '2', '8', '12', '1', '64', None], dtype=object)

# %%
flip.rom.unique()
# Out:
# array(['64', '128', '32', '256', '0', '16', '8', '4', '512', None],
#       dtype=object)

# %%
flip.prices.unique()
# Out:
# array(['₹8,799', '₹27,999', '₹11,499', '₹12,499', '₹10,499', '₹9,499',
#        '₹13,999', '₹8,999', '₹7,999', '₹15,999', '₹16,999', '₹7,499',
#        '₹9,990', '₹10,990', '₹17,999', '₹15,990', '₹12,999', '₹41,999',
#        '₹9,999', '₹9,299', '₹11,999', '₹52,999', '₹10,999', '₹1,367',
#        '₹24,999', '₹979', '₹20,350', '₹1,159', '₹15,499', '₹13,499',
#        '₹880', '₹15,490', '₹1,599', '₹17,499', '₹34,990', '₹1,199',
#        '₹729', '₹14,499', '₹14,999', '₹1,219', '₹19,999', '₹13,583',
#        '₹17,439', '₹759', '₹1,029', '₹5,999', '₹849', '₹996', '₹1,375',
#        '₹13,775', '₹13,990', '₹29,990', '₹24,254', '₹1,348', '₹1,299',
#        '₹11,990', '₹19,490', '₹1,752', '₹1,245', '₹16,490', '₹749',
#        '₹1,099', '₹1,575', '₹799', '₹2,499', '₹6,999', '₹1,499',
#        '₹13,490', '₹839', '₹1,480', '₹1,311', '₹1,240', '₹1,049',
#        '₹23,499', '₹6,199', '₹985', '₹15,989', '₹15,023', '₹1,080',
#        '₹16,599', '₹14,983', '₹1,154', '₹14,489', '₹1,400', '₹10,675',
# ...

# %%
flip.colours.unique()
# Out:
# array(['Metallic Blue', 'Coral Green', 'Red', 'Oxygen Green',
#        'Oxygen Blue', 'Carbon Black', 'Cross Black', 'Cross Blue',
#        'Space Black', 'Shadow Gray', 'Royal Blue', 'Space Purple',
#        'Frosted Champagne', 'Cool Grey', 'Cool Blue', 'Mint Green',
#        'Black', 'Flowing Silver', 'Blue', 'Cyber Black', 'Prism Blue',
#        'Deep Blue', 'Sea Blue', 'Cyber Silver', 'Ink Black',
#        'Crystal Blue', 'Baby Blue', 'Dynamic Gray', 'Prism Black',
#        'Tahiti Blue', 'Denim Black', 'Sky Blue', 'Green Wave',
#        'Heart Of Ocean', '7° Purple', '95° Black', 'Metal Grey',
#        'Glacier Blue', 'Midnight Black', 'Denim Blue', 'Morandi Green',
#        'Polar Black', 'Sea Green', 'Nokia TA-1304/105 SS', 'Purple Mist',
#        'LAVA A1 Josh 2021', 'LAVA A3', 'Racing Silver', 'Micromax X412',
#        'Obsidian Black', 'LAVA GEM', 'Matte Black', 'Shadow Black',
#        'Sunshine Gold', 'LAVA A1500', 'Haze Green', 'I Kall K 48',
# ...

# %%
flip.front_camera_in_MP.unique()
# Out:
# array(['5MP Front Camera', '7MP Front Camera', '8MP Front Camera',
#        '16MP Front Camera', '32MP Front Camera', '13MP Front Camera',
#        '12MP Front Camera', '20MP Front Camera', '0MP Front Camera',
#        '0.3MP Front Camera', '2MP Front Camera', '48MP Front Camera',
#        '44MP Front Camera', '10MP Front Camera', None], dtype=object)

# %%
flip.back_camera_in_MP.unique()
# Out:
# array(['13MP Rear Camera', '12MP Rear Camera', '50MP + 2MP + 2MP',
#        '13MP + 2MP + 2MP', '108MP + 8MP + 2MP', '8MP Rear Camera',
#        '13MP + 2MP', '64MP + 8MP + 2MP + 2MP', '50MP + 8MP + 2MP',
#        '48MP + 8MP + 2MP + 2MP', '48MP + 5MP + 2MP + 2MP', '12MP + 12MP',
#        '50MP + 2MP + AI Lens', '48MP + 2MP + AI Lens Camera',
#        '13MP + Depth Sensor', '108MP Rear Camera',
#        '48MP + 8MP + 5MP + 2MP', '48MP + 2MP + 2MP', '64MP + 5MP + 2MP',
#        '50 MP + 2 MP Depth Lens + 2 MP Macro Lens', '64MP + 8MP + 2MP',
#        '64MP + 2MP + 2MP', '13MP + Digital Camera',
#        '64MP + 12MP + 5MP + 5MP', '50 MP + 2 MP + AI Lens',
#        '64MP + 8MP + 5MP + 5MP', '5MP Rear Camera',
#        '50MP + 8MP + 2MP + 2MP', '0MP', '8MP + 0.3MP', '48MP + 5MP + 2MP',
#        '0.3MP Rear Camera', '13MP + 8MP + 5MP + 2MP', '48MP + 2MP',
#        '13MP + AI Lens Dual AI Camera', '48MP + 8MP + 2MP',
# ...

# %%
flip.screen_size.unique()
# Out:
# array(['6.53', '4.7', '6.5', '6.6', '6.78', '6.22', '6.4', '6.52', '6.47',
#        '6.8', '6.51', '6.515', '5.4', '6.82', '6.1', '1.77', '6.67',
#        '2.8', '6.43', '6.44', '2.4', '6.95', '1.8', '1.4', '2.6', '6.58',
#        '1.52', '1.44', '6.7', '6.49', '0.66', '6.088', '5.45', '6.26',
#        '6.517', '6.55', '5.81', '1.54', '6.56', '1.5', '6.62', '6.65',
#        '1.7', '6.08', '6.2', '5.5', '5.99', '7.6', '2.2', '5.84', '5.8',
#        '6.3', '1.75', '1.14', '6.57', None], dtype=object)

# %%
flip.batteries_in_mAh.unique()
# Out:
# array(['5000', '6000', '4230', '800', '5160', '1750', '4200', '1800',
#        '1500', '2575', '620', '4500', '2500', '1200', '950', '1000',
#        '850', '3600', '1900', '3000', '5020', '1020', '2550', '1100',
#        '4000', '1700', '2000', '5065', '1400', '4300', '5050', '2400',
#        '4310', '5018', '1050', '4250', '3020', '3140', '300', '2800',
#        '2050', '1450', '2502', '400', '750', '4520', '2700', '3950',
#        '550', '700', '4998', '4450', '1300', '4100', '3080', '4400',
#        '1150', '4820', '4630', '5200', '4015', '2200', None], dtype=object)

# %%
flip.processor.unique()
# Out:
# array(['MediaTek Helio G25 Processor',
#        'A13 Bionic Chip with 3rd Gen Neural Engine Processor',
#        'MediaTek Helio G85 Processor', 'Unisoc T610 Processor',
#        'MediaTek Helio G96 Processor', 'MediaTek Helio G35 Processor',
#        'Qualcomm Snapdragon 732G Processor', 'Octa-core Processor',
#        'SC9863A Processor', 'MediaTek Helio P35 Processor',
#        'MediaTek Helio G95 Processor',
#        'Qualcomm Snapdragon 680 (SM6225) Processor',
#        'MediaTek Dimensity 700 Processor', 'Mediatek Helio G85 Processor',
#        'MediaTek Helio G80 Processor', 'Exynos 850 Processor',
#        'A14 Bionic Chip with Next Generation Neural Engine Processor',
#        'MediaTek Helio G88 Processor', 'Unisoc T610 Octa Core Processor',
#        'Unisoc T618 Processor', 'Mediatek Dimensity 920 Processor',
#        'Dimensity 720 5G Processor', 'Qualcomm Snapdragon 662 Processor',
#        'NA Processor', 'Mediatek Helio G95 Processor',
# ...

# %% [markdown]
# ## Changing Datatypes

# %%
flip['rating'] = flip['rating'].apply(lambda x : float(x))

# %%
flip['rom'].unique()
# Out:
# array(['64', '128', '32', '256', '0', '16', '8', '4', '512', None],
#       dtype=object)

# %%
flip['rom'].mode()
# Out:
# 0    128
# dtype: object

# %%
flip['rom'] = flip['rom'].apply(lambda x : str(x).replace('None','64'))

# %%
flip['rom'] = flip['rom'].apply(lambda x : int(x))

# %%
flip['screen_size'].median()
# Out:
# 6.1

# %%
flip['screen_size'] = flip['screen_size'].apply(lambda x : str(x).replace('None','6.4'))

# %%
flip['screen_size'] = flip['screen_size'].apply(lambda x : float(x))

# %%
flip['ram'] = flip['ram'].apply(lambda x :str(x).replace('None','4'))

# %%
flip['ram'] = flip['ram'].apply(lambda x : int(x))

# %%
flip['prices'] = flip['prices'].apply(lambda x : str(x).replace('₹',''))

# %%
flip['prices'] = flip['prices'].apply(lambda x : str(x).replace(',',''))

# %%
flip['prices'] = flip['prices'].apply(lambda x : str(x).replace('None','888888888888888'))

# %%
flip['prices'] = flip['prices'].apply(lambda x : int(x))

# %%
flip['prices'].median()
# Out:
# 7880.0

# %%
flip['prices'] = flip['prices'].apply(lambda x : str(x).replace('888888888888888','7999'))

# %%
flip['prices'] = flip['prices'].apply(lambda x : int(x))

# %%
flip['front_camera_in_MP'].unique()
# Out:
# array(['5MP Front Camera', '7MP Front Camera', '8MP Front Camera',
#        '16MP Front Camera', '32MP Front Camera', '13MP Front Camera',
#        '12MP Front Camera', '20MP Front Camera', '0MP Front Camera',
#        '0.3MP Front Camera', '2MP Front Camera', '48MP Front Camera',
#        '44MP Front Camera', '10MP Front Camera', None], dtype=object)

# %%
flip['front_camera_in_MP'].mode()
# Out:
# 0    8MP Front Camera
# dtype: object

# %%
flip['front_camera_in_MP'] = flip['front_camera_in_MP'].apply(lambda x : str(x).replace('MP Front Camera',''))

# %%
flip['front_camera_in_MP'] = flip['front_camera_in_MP'].apply(lambda x : str(x).replace('None','5'))

# %%
flip['front_camera_in_MP'].unique()
# Out:
# array(['5', '7', '8', '16', '32', '13', '12', '20', '0', '0.3', '2', '48',
#        '44', '10'], dtype=object)

# %%
flip['front_camera_in_MP'] = flip['front_camera_in_MP'].apply(lambda x : float(x))

# %%
flip['back_camera_in_MP'] = flip['back_camera_in_MP'].apply(lambda x : str(x).replace('MP Rear Camera',''))

# %%
flip.rename(columns = {'front_camera':'front_camera_in_MP','back_camera':'back_camera_in_MP'},inplace = True)

# %%
flip['batteries_in_mAh'] = flip['batteries_in_mAh'].apply(lambda x : str(x).replace('None','5000'))

# %%
flip['batteries_in_mAh'] = flip['batteries_in_mAh'].apply(lambda x : int(x))

# %%
flip['rom'] = flip['rom'].apply(lambda x : str(x).replace('512','0.512'))

# %%
flip['ram'] = flip['ram'].apply(lambda x : str(x).replace('64','0.64'))

# %%
flip['ram'] = flip['ram'].apply(lambda x : float(x))

# %%
flip['rom'] = flip['rom'].apply(lambda x : float(x))

# %%
flip.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 960 entries, 0 to 959
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   mobile_name         960 non-null    object
#  1   brand               960 non-null    object
#  2   rating              960 non-null    float64
#  3   ram                 960 non-null    int64
#  4   rom                 960 non-null    float64
#  5   prices              960 non-null    int64
#  6   colours             960 non-null    object
#  7   front_camera_in_MP  960 non-null    float64
#  8   back_camera_in_MP   960 non-null    object
#  9   screen_size         960 non-null    float64
#  10  batteries_in_mAh    960 non-null    int64
#  11  processor           534 non-null    object
# dtypes: float64(4), int64(3), object(5)
# memory usage: 90.1+ KB

# %% [markdown]
# # Exploratory Data Analysis

# %% [markdown]
# # Univariate Analysis

# %%
sns.displot(flip.rating,kind='kde');

# %%
flip.rating.max()
#maximum rating given to mobile phones is 5.0
# Out:
# 5.0

# %%
flip.loc[flip.rating==flip.rating.max(),:]
# these mobiles have highest rating
# Out:
#                         mobile_name      brand  rating  ram   rom  prices  \
# 479  Kechaoda K66 The Music House 4   Kechaoda     5.0    8  32.0   15490
# 623                    Snexian BOLD    Snexian     5.0    4  64.0    1350
# 727                      Mi 11 Lite         Mi     5.0    4  64.0    1499
# 742            BlackZone B-310 GOLD  BlackZone     5.0    4  64.0   20999
# 763                        MTR M900        MTR     5.0    4  64.0  119900
# 790                        OPPO F19       OPPO     5.0    4  64.0    1399
# 839                       OPPO A16k       OPPO     5.0    4  64.0     799
# 863                          YU Ace         YU     5.0    4  64.0   41999
# 911                        vivo Y30       vivo     5.0    4  64.0  179900
# 934            SAMSUNG Guru Music 2    SAMSUNG     5.0    4  64.0   22450
# 959      SAMSUNG Metro 313 Dual Sim    SAMSUNG     5.0    4  64.0    7999
#
#                             colours  front_camera_in_MP back_camera_in_MP  \
# ...

# %%
flip.loc[flip.rating==flip.rating.max(),:].brand.value_counts()
#maximum rating belongs to the brand mobiles
# Out:
# OPPO         2
# SAMSUNG      2
# YU           1
# Mi           1
# MTR          1
# Kechaoda     1
# vivo         1
# Snexian      1
# BlackZone    1
# Name: brand, dtype: int64

# %%
flip.rating.min()
# this is the minimum rating for mobile phone
# Out:
# 1.0

# %%
flip.loc[flip.rating==flip.rating.min(),:]
# these are the mobiles which got lowest rating
# Out:
#       mobile_name     brand  rating  ram   rom  prices       colours  \
# 743  Kechaoda A32  Kechaoda     1.0    4  64.0     799  Kechaoda A32
# 791  REDMI Note 9     REDMI     1.0    4  64.0     849  Arctic White
# 815     MTR Mt312       MTR     1.0    4  64.0    7449     MTR Mt312
# 838     OPPO A16k      OPPO     1.0    4  64.0   17990         Black
#
#      front_camera_in_MP back_camera_in_MP  screen_size  batteries_in_mAh  \
# 743                 5.0              None         6.53               400
# 791                 5.0              None         6.55               800
# 815                 5.0              None         6.58              1900
# 838                 5.0              None         1.80              5000
#
#     processor
# 743      None
# 791      None
# 815      None
# 838      None

# %%
flip.loc[flip.rating==flip.rating.min(),:].brand.value_counts()
# minimum rating belongs to these companies
# Out:
# OPPO        1
# Kechaoda    1
# REDMI       1
# MTR         1
# Name: brand, dtype: int64

# %%
flip.loc[flip.brand=='realme',:].rating.max()
# maximum rating realme brand got is 4.6
# Out:
# 4.6

# %%
flip.loc[flip.brand=='realme',:].rating.min()
# minimum rating realme brand got is 3.9
# Out:
# 3.9

# %%
flip.loc[flip.brand=='realme',:].rating.value_counts()
# maximum of 4.4 rating is got to realme brand mobile phones
# Out:
# 4.4    42
# 4.3    16
# 4.5    14
# 4.6     2
# 4.2     2
# 4.0     2
# 3.9     1
# Name: rating, dtype: int64

# %%
flip.loc[flip.brand=='realme',:].rating.value_counts().plot(kind = "pie");

# %%
flip.loc[flip.brand=='realme',:].ram.value_counts()
# most of frealme mobiles have 4GB ram
# Out:
# 4     39
# 6     15
# 8     10
# 3      9
# 2      5
# 12     1
# Name: ram, dtype: int64

# %%
flip.loc[flip.brand=='realme',:].ram.value_counts().plot(kind = "barh",color=sns.color_palette("hls",5));

# %%
flip.loc[flip.brand=='realme',:]['front_camera_in_MP'].value_counts()
# most of realme phones have front camera of 5 MP
# Out:
# 5.0     36
# 16.0    23
# 8.0     12
# 20.0     5
# 32.0     2
# 13.0     1
# Name: front_camera_in_MP, dtype: int64

# %%
flip.loc[flip.brand=='realme',:]['front_camera_in_MP'].value_counts().plot(kind = "pie");

# %%
flip.loc[flip.brand=='realme',:].prices.value_counts()
# these are the prices of realme phones
# Out:
# 11999    7
# 10499    5
# 9499     5
# 8999     5
# 7499     4
# 13999    4
# 15999    4
# 10999    3
# 1096     2
# 16999    2
# 19999    2
# 17999    2
# 7999     2
# 13499    2
# 1229     1
# 7890     1
# 12499    1
# 3850     1
# 1319     1
# 15499    1
# 1194     1
# 1780     1
# 1269     1
# 1699     1
# 29999    1
# 14590    1
# 11499    1
# 12999    1
# 15989    1
# 1107     1
# 1349     1
# 999      1
# 26940    1
# 15799    1
# 12980    1
# 8499     1
# 799      1
# 18090    1
# 735      1
# 1099     1
# 14499    1
# 1440     1
# 20499    1
# 6590     1
# Name: prices, dtype: int64

# %%
plt.figure(figsize=(15,5))
flip.loc[flip.brand=='realme',:].prices.value_counts().plot(kind='bar',color=sns.color_palette("hls",5));

# most of realme phone are of 11999 price range

# %%
flip.loc[flip.brand=='POCO',:].batteries_in_mAh.value_counts()
# most of POCO phones have 5000 mAh battery
# Out:
# 5000    8
# 4000    1
# 4300    1
# 850     1
# 4500    1
# 5050    1
# 1020    1
# Name: batteries_in_mAh, dtype: int64

# %%
flip.loc[flip.brand=='POCO',:].batteries_in_mAh.value_counts().plot(kind='pie');

# %%
flip.loc[flip.brand=='APPLE',:].batteries_in_mAh.value_counts()
# Most of Apple phones have 5000 mAh battery
# Out:
# 5000    12
# 1000     7
# 6000     5
# 1800     2
# 4230     2
# 800      2
# 2800     1
# 5200     1
# 850      1
# 4500     1
# 1500     1
# 3000     1
# 1200     1
# Name: batteries_in_mAh, dtype: int64

# %%
flip.loc[flip.brand=='APPLE',:].batteries_in_mAh.value_counts().plot(kind='bar',color=sns.color_palette("hls",5));

# %%
flip.rating.value_counts()

# most of the mobile phones got the rating of 4.3
# Out:
# 4.3    216
# 4.2    125
# 4.1    114
# 4.0    112
# 3.9     89
# 4.4     89
# 3.8     50
# 4.5     33
# 3.6     32
# 3.7     31
# 4.6     21
# 4.7     14
# 5.0     11
# 3.5      8
# 3.3      4
# 1.0      4
# 3.2      2
# 3.0      2
# 2.0      1
# 3.1      1
# 3.4      1
# Name: rating, dtype: int64

# %%
flip.rating.value_counts().plot(kind = "bar",color=sns.color_palette("hls",5))
plt.ylabel("rating")
plt.xlabel("Count")
plt.title("rating")
plt.show()

# %%
sns.displot(flip.ram,kind='kde');

# most of the mobile phones have ram memory of 1-10 GB

# %%
flip.ram.value_counts()
# most of the mobiles have 4 GB of memory
# Out:
# 4     622
# 6     116
# 8      97
# 2      55
# 3      53
# 12      9
# 1       6
# 64      2
# Name: ram, dtype: int64

# %%
flip.loc[flip.brand=='realme',:].rom.value_counts()
# most of realme phones have 64 GB rom
# Out:
# 64.0     38
# 128.0    24
# 32.0     14
# 256.0     3
# Name: rom, dtype: int64

# %%
flip.loc[flip.brand=='realme',:].rom.value_counts().plot(kind='pie');

# %%
flip.loc[flip.brand=='realme',:].colours.value_counts()
# most of realme phone are available in 'Cross Black' colour
# Out:
# Cross Black        6
# Cross Blue         4
# Metal Grey         4
# Cool Blue          3
# Cool Grey          3
# Mist Blue          3
# NEO Black          3
# Racing Silver      3
# Mint Green         3
# Power Silver       3
# Cyber Black        3
# Prism Blue         2
# Watery Grey        2
# Asteroid Black     2
# Cosmos Black       2
# Blade Silver       2
# Watery Blue        2
# Universe Purple    2
# Glacier Blue       2
# Cyber Silver       2
# Space Black        2
# Carbon Black       2
# Prism Black        2
# Oxygen Blue        1
# Voyager Grey       1
# Oxygen Green       1
# Mercury Silver     1
# Nebula             1
# Rich Green         1
# Moss Green         1
# Milky Way          1
# NEO Green          1
# Daybreak Blue      1
# Sword Black        1
# Arctic White       1
# Space Purple       1
# Dashing Blue       1
# Power Blue         1
# NEO Blue           1
# Infinite Black     1
# Name: colours, dtype: int64

# %%
plt.figure(figsize=(15,15))

flip.loc[flip.brand=='realme',:].colours.value_counts().plot(kind='pie');

# %%
flip.ram.value_counts()
# Most of the phones have 4GB ram memory
# Out:
# 4.00     622
# 6.00     116
# 8.00      97
# 2.00      55
# 3.00      53
# 12.00      9
# 1.00       6
# 0.64       2
# Name: ram, dtype: int64

# %%
flip.ram.value_counts().plot(kind = "barh",color=sns.color_palette("hls",5))
plt.ylabel("ram")
plt.xlabel("Count")
plt.title("ram")
plt.show()

# %%
flip.loc[flip.ram==12,:].brand.value_counts()
# these are the phones which have 12 GB ram memory
# Out:
# LAVA         2
# SAMSUNG      2
# Maplin       1
# realme       1
# Itel         1
# Ismart       1
# BlackZone    1
# Name: brand, dtype: int64

# %%
flip.loc[flip.ram==12,:].brand.value_counts().plot(kind='bar',color=sns.color_palette("hls",5));

# %%
flip.loc[flip.prices==flip.prices.max(),:]
# vivo Y30 is the phone which have higest price
# Out:
#     mobile_name brand  rating  ram   rom  prices        colours  \
# 911    vivo Y30  vivo     5.0  4.0  64.0  179900  Emerald Black
#
#      front_camera_in_MP back_camera_in_MP  screen_size  batteries_in_mAh  \
# 911                 5.0              None          1.8              2200
#
#     processor
# 911      None

# %%
flip.loc[flip.rating==flip.rating.max(),:]
# the are the phones which have maximum rating of 5.0
# Out:
#                         mobile_name      brand  rating  ram   rom  prices  \
# 479  Kechaoda K66 The Music House 4   Kechaoda     5.0  8.0  32.0   15490
# 623                    Snexian BOLD    Snexian     5.0  4.0  64.0    1350
# 727                      Mi 11 Lite         Mi     5.0  4.0  64.0    1499
# 742            BlackZone B-310 GOLD  BlackZone     5.0  4.0  64.0   20999
# 763                        MTR M900        MTR     5.0  4.0  64.0  119900
# 790                        OPPO F19       OPPO     5.0  4.0  64.0    1399
# 839                       OPPO A16k       OPPO     5.0  4.0  64.0     799
# 863                          YU Ace         YU     5.0  4.0  64.0   41999
# 911                        vivo Y30       vivo     5.0  4.0  64.0  179900
# 934            SAMSUNG Guru Music 2    SAMSUNG     5.0  4.0  64.0   22450
# 959      SAMSUNG Metro 313 Dual Sim    SAMSUNG     5.0  4.0  64.0    7999
#
#                             colours  front_camera_in_MP back_camera_in_MP  \
# ...

# %%
flip.loc[flip.ram==flip.ram.max(),:]
# these are the phones which has max ram of 12 GB
# Out:
#                mobile_name      brand  rating   ram    rom  prices  \
# 75   SAMSUNG Galaxy M32 5G    SAMSUNG     4.2  12.0   64.0   20350
# 311  Ismart IS-101 Ferrari     Ismart     3.9  12.0  128.0    9999
# 329           realme 8 Pro     realme     4.4  12.0  128.0    8499
# 356        Maplin Map3 Max     Maplin     3.8  12.0  128.0    7499
# 358                LAVA Z2       LAVA     4.2  12.0  128.0    2440
# 380      BlackZone PRITHVI  BlackZone     3.6  12.0   32.0    1159
# 393                LAVA A5       LAVA     4.1  12.0  128.0    1168
# 446            Itel it5026       Itel     4.1  12.0  128.0   26940
# 460        SAMSUNG GURU GT    SAMSUNG     4.6  12.0   16.0    1299
#
#                    colours  front_camera_in_MP         back_camera_in_MP  \
# 75                Sky Blue                16.0          48MP + 2MP + 2MP
# 311  Ismart IS-101 Ferrari                12.0               12MP + 12MP
# 329         Infinite Black                20.0          64MP + 8MP + 5MP
# ...

# %%
flip.loc[flip.rom==flip.rom.max(),:]
# these are the phones which has maximum rom memory of 256 GB
# Out:
#                    mobile_name     brand  rating  ram    rom  prices  \
# 79               Micromax X412  Micromax     3.9  6.0  256.0     880
# 109              Xiaomi 11i 5G    Xiaomi     4.3  6.0  256.0   24999
# 120                 realme C21    realme     4.4  6.0  256.0   10499
# 170                   vivo Y21      vivo     4.3  6.0  256.0   13990
# 209             REDMI 10 Prime     REDMI     4.2  4.0  256.0   15989
# 246             REDMI 10 Prime     REDMI     4.2  1.0  256.0   14700
# 300                Itel IT2163      Itel     4.2  6.0  256.0    8490
# 323                  Nokia G20     Nokia     4.0  6.0  256.0    3567
# 343   I Kall K55 Keypad Mobile         I     3.8  2.0  256.0   14999
# 371                   OPPO A31      OPPO     4.3  8.0  256.0   26999
# 373  Xiaomi 11i Hypercharge 5G    Xiaomi     4.2  4.0  256.0     799
# 377               OPPO F19 Pro      OPPO     4.3  6.0  256.0   25890
# 396             Tecno Spark 7T     Tecno     4.2  4.0  256.0     859
# ...

# %%
flip.loc[flip.screen_size==flip.screen_size.max(),:]
# this the phone which has maximum screen size
# Out:
#     mobile_name brand  rating  ram   rom  prices colours  front_camera_in_MP  \
# 807      MTR M4   MTR     3.9  4.0  64.0    1194  MTR M4                 5.0
#
#     back_camera_in_MP  screen_size  batteries_in_mAh processor
# 807              None          7.6              1800      None

# %%
flip.loc[flip.batteries_in_mAh==flip.batteries_in_mAh.max(),:]['brand'].value_counts()
# these are the brands with maximum battery capacity of 6000 mAh
# Out:
# realme       11
# SAMSUNG       8
# LAVA          5
# APPLE         5
# Infinix       4
# Kechaoda      4
# BlackZone     4
# MOTOROLA      3
# Itel          3
# KARBONN       3
# Micromax      2
# Tecno         2
# Infocus       2
# Nokia         2
# REDMI         2
# vivo          2
# I             1
# GFive         1
# OPPO          1
# Xiaomi        1
# Mi            1
# Redmi         1
# INOVU         1
# Geotel        1
# Name: brand, dtype: int64

# %%
flip.loc[flip.prices==flip.prices.min(),:]
# this the phone with lowest price
# Out:
#     mobile_name  brand  rating  ram    rom  prices   colours  \
# 222    GFive A2  GFive     3.6  1.0  128.0     699  GFive A2
#
#      front_camera_in_MP  back_camera_in_MP  screen_size  batteries_in_mAh  \
# 222                16.0  108MP + 8MP + 2MP          6.4              5000
#
#                         processor
# 222  MediaTek Helio G80 Processor

# %%
flip.mobile_name.value_counts()
# Out:
# SAMSUNG Galaxy A12         10
# Kechaoda K115              10
# APPLE iPhone 13 Mini        9
# Kechaoda K33                9
# REDMI Note 9                9
#                            ..
# Grabo G312                  1
# ENERGIZER Hardcase E100     1
# Kechaoda K9                 1
# Zoom Me M2                  1
# Nokia 150 TA-1235 DS        1
# Name: mobile_name, Length: 424, dtype: int64

# %%
flip.loc[flip.colours=='Carbon Black',:].mobile_name.value_counts()
# these are the phones which has 'Carbon Black' colour phones
# Out:
# realme Narzo 50i    2
# REDMI 9i Sport      1
# Redmi 9A Sport      1
# Name: mobile_name, dtype: int64

# %%
flip.rom.value_counts().plot(kind = "barh",color=sns.color_palette("hls",5))
plt.ylabel("rom")
plt.xlabel("Count")
plt.title("ram")
plt.show()

# most of the phone are of 64 GB rom

# %%
sns.displot(flip.batteries_in_mAh,kind='kde');
# most of the phone have batteries of 6000 mAh

# %%
sns.displot(flip.batteries_in_mAh,kind='hist');

# most of the phone have batteries of 5000-5500 mAh

# %%
sns.boxplot(flip.batteries_in_mAh);
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
plt.figure(figsize = (12,7))

flip.batteries_in_mAh.value_counts().plot(kind = "bar",color=sns.color_palette("hls",10))
plt.ylabel("batteries_in_mAh")
plt.xlabel("Count")
plt.title("batteries_in_mAh")
plt.show()

# most of the mobile phones have the battery of around 5000 mAh

# %%
flip1 = flip.groupby('brand')

# %%
flip1.get_group('APPLE')['prices'].mean()
# the mean price of apple phone is 14254
# Out:
# 14254.675675675675

# %%
flip1.get_group('REDMI')['prices'].mean()
# the mean price of READMI phone is 14130
# Out:
# 14130.160714285714

# %%
flip1.get_group('POCO')['prices'].mean()

# the mean price of POCO phone is 5481
# Out:
# 5481.571428571428

# %%
flip1.get_group('MOTOROLA')['prices'].mean()
# the mean price of MOTOROLA phone is 13954
# Out:
# 13954.78947368421

# %%
flip1.get_group('OPPO')['prices'].mean()
# the mean price of OPPO phone is 16369
# Out:
# 16369.106382978724

# %%
flip1.get_group('SAMSUNG')['prices'].mean()
# the mean price of SAMSUNG phone is 12350
# Out:
# 12350.7625

# %%
flip1.get_group('Nokia')['prices'].mean()
# the mean price of NOKIA phone is 10390
# Out:
# 10390.857142857143

# %%
flip1.get_group('MI')['prices'].mean()
# the mean price of MI phone is 5654
# Out:
# 5654.5

# %%
flip.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 960 entries, 0 to 959
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   mobile_name         960 non-null    object
#  1   brand               960 non-null    object
#  2   rating              960 non-null    float64
#  3   ram                 960 non-null    float64
#  4   rom                 960 non-null    float64
#  5   prices              960 non-null    int64
#  6   colours             960 non-null    object
#  7   front_camera_in_MP  960 non-null    float64
#  8   back_camera_in_MP   960 non-null    object
#  9   screen_size         960 non-null    float64
#  10  batteries_in_mAh    960 non-null    int64
#  11  processor           534 non-null    object
# dtypes: float64(5), int64(2), object(5)
# memory usage: 90.1+ KB

# %% [markdown]
# # Bivariate Plots

# %%
plt.figure(figsize = (12,12))

plt.scatter(flip['prices'],flip['brand'])
plt.xticks(rotation = 90)
plt.title('prices Vs brand',size = 25 )
plt.xlabel('prices')
plt.ylabel('brand')
plt.show()

# the Maximum price is of vivo brand

# %%
plt.figure(figsize =(10,7))

sns.barplot(flip['rating'],flip['screen_size']);

plt.xticks(rotation = 90)

plt.xlabel('rating')
plt.ylabel('screen_size')
plt.show()

# the most rated screen size is of 6.8 inches
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
plt.figure(figsize =(10,7))

sns.barplot(flip['rating'],flip['prices']);

plt.xticks(rotation = 90)

plt.xlabel('rating')
plt.ylabel('prices')
plt.show()

# the most rated phone is of price around 40,000
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
plt.figure(figsize =(20,10))

sns.boxplot(flip['brand'],flip['prices'])

plt.xticks(rotation = 90)

plt.xlabel('brand')
plt.ylabel('prices')
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
plt.figure(figsize =(20,8))
sns.barplot(flip['brand'],flip['rating'])
plt.xticks(rotation = 90)

plt.xlabel('brand')
plt.ylabel('rating')
plt.show()
# YU is the most rated brand
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
plt.figure(figsize =(10,7))
sns.barplot(flip['ram'],flip['front_camera_in_MP'])
plt.xticks(rotation = 90)

plt.xlabel('ram')
plt.ylabel('front_camera_in_MP')
plt.show()

# 12 GB ram phones has a front camera of 24 MP camera
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
plt.figure(figsize =(10,7))
sns.barplot(flip['rom'],flip['prices'])
plt.xticks(rotation = 90)

plt.xlabel('rom')
plt.ylabel('prices')
plt.show()

# 4 GB rom mobiles are of range 15,000
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
plt.figure(figsize =(10,7))
sns.barplot(flip['ram'],flip['prices'])
plt.xticks(rotation = 90)

plt.xlabel('ram')
plt.ylabel('prices')
plt.show()

# 4 GB ram mobiles has a price range of around 13500
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
flip.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 960 entries, 0 to 959
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   mobile_name         960 non-null    object
#  1   brand               960 non-null    object
#  2   rating              960 non-null    float64
#  3   ram                 960 non-null    float64
#  4   rom                 960 non-null    float64
#  5   prices              960 non-null    int64
#  6   colours             960 non-null    object
#  7   front_camera_in_MP  960 non-null    float64
#  8   back_camera_in_MP   960 non-null    object
#  9   screen_size         960 non-null    float64
#  10  batteries_in_mAh    960 non-null    int64
#  11  processor           534 non-null    object
# dtypes: float64(5), int64(2), object(5)
# memory usage: 90.1+ KB

# %% [markdown]
# # Multivariate Plots

# %%
sns.pairplot(flip)

# %%
plt.figure(figsize = (10,8))

sns.heatmap(flip.corr());
